# %% [raw]
#  API KEY
#  53f964f0115fa5df324a07f7609f4eb2
#  53f964f0115fa5df324a07f7609f4eb2
# https://developers.zomato.com/api#headline2
# 46a32d6f984df085f770e2dd70a9889f

# %% [raw]
# Project Details
# Send Feedback
# For this project, we are using the Zomato API.
# Zomato APIs give you access to the freshest and most exhaustive information for over 1.5 million restaurants across 10,000 cities globally.
# Zomato API documentation link
# Our Motivation for using Zomato API
# By Collecting the data using Zomato API one can recommend restaurants on the basis of user’s affinity to specific cuisines, establishment types, locations, and price bands.
# We can find out whether restaurant support online reservation or not.
# We can find what is the most popular and/ or exclusive/new at a given location & time.

# %% [raw]
# Zomato cuisine problem details
# Send Feedback
# Mexican cuisine began about 9,000 years ago, when agricultural communities such as the Maya formed, domesticating maize, creating the standard process of corn nixtamalization, and establishing their foodways.
# You are a huge fan of ‘Mexican’ cuisine. Now using the Zomato API you want to analyse the best restaurant serving the Mexican Cuisine, their locations, and cost for two, etc.
# There is a list of questions related to Mexican cuisines given in the next section.

# %% [raw]
# Zomato Cuisine 1.1
# Send Feedback
# Fetch the cuisine_id of ‘Mexican’ cuisine using Zomato API.
# Print the cuisine_id.
# Output Format:
# cuisine_id

# %%
import requests
import json

# %%
h ={"Accept: application/json"}
r = requests.get('https://developers.zomato.com/api/v2.1/search', headers = {'user-key':'46a32d6f984df085f770e2dd70a9889f'})
r
# Out:
# <Response [200]>

# %%
data = r.json()
data
# Out:
# {'results_found': 1511003,
#  'results_start': 0,
#  'results_shown': 20,
#  'restaurants': [{'restaurant': {'R': {'res_id': 17779802,
#      'is_grocery_store': False,
#      'has_menu_status': {'delivery': -1, 'takeaway': -1}},
#     'apikey': '46a32d6f984df085f770e2dd70a9889f',
#     'id': '17779802',
#     'name': 'Asian House',
#     'url': 'https://www.zomato.com/florence-roebling-nj/asian-house-bordentown?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'location': {'address': '2144 US 130, Bordentown 08505',
#      'locality': 'Florence-Roebling',
#      'city': 'Florence-Roebling',
#      'city_id': 10720,
#      'latitude': '40.1102467000',
#      'longitude': '-74.7729457000',
#      'zipcode': '08505',
#      'country_id': 216,
#      'locality_verbose': 'Florence-Roebling, Florence-Roebling'},
#     'switch_to_order_menu': 0,
#     'cuisines': 'Chinese, Japanese, Sushi',
# ...

# %%
print(r.url)
# Out:
# https://developers.zomato.com/api/v2.1/search

# %%
import json 
import requests
h = {'user-key' :'53f964f0115fa5df324a07f7609f4eb2'}
params = { 'q' : 'New Delhi', 'count': 1 }
r  =  requests.get('https://developers.zomato.com/api/v2.1/search',headers = h, params = params)
data = r.json()
city_id = data['restaurants'][0]['restaurant']['location']['city_id']
# Out:
# 3

# %%
params = {'city_id': city_id}
r  =  requests.get('https://developers.zomato.com/api/v2.1/cuisines',headers = h, params = params)
data = r.json()
for i in data ['cuisines']:
    if i ['cuisine']['cuisine_name'] == 'BBQ':
        print(i['cuisine']['cuisine_id'])
# Out:
# 193

# %%
import json 
import requests

h = {'Accept': 'application/json' ,'user-key' :'53f964f0115fa5df324a07f7609f4eb2'}
r  =  requests.get('https://developers.zomato.com/api/v2.1/search?entity_id=104&entity_type=subzone&count=10&cuisines=73&sort=rating&order=desc',headers = h)
data = r.json()
for i in data['restaurants']:
    print(i['restaurant']['name'], i ['restaurant']['user_rating']['aggregate_rating'], i['restaurant']['R']['res_id'])
# Out:
# Station Bar 4.6 18851371
# Farzi Cafe 4.5 18233593
# Tamasha 4.4 18238278
# Ministry Of Beer 4.4 18418277
# Master Of Malts 4.4 18391149
# Chili's Grill & Bar 4.4 18537536
# Local 4.3 18382360
# Xero Degrees 4.3 18729557
# The Junkyard Cafe 4.3 313256
# Teddy Boy 4.3 18281985

# %%
import json 
import requests

h = {'Accept': 'application/json' ,'user-key' :'53f964f0115fa5df324a07f7609f4eb2'}
r  =  requests.get('https://developers.zomato.com/api/v2.1/search?entity_id=104&entity_type=subzone&cuisines=73&category=6&sort=rating&order=desc',headers = h)
data = r.json()
for i in data['restaurants']:
    print(i['restaurant']['name'], i ['restaurant']['user_rating']['aggregate_rating'], i['restaurant']['R']['res_id'])
# Out:
# Xero Degrees 4.3 18729557
# Chaayos - Meri Wali Chai 4.1 18237315
# The Art House Bar n Cafe 4.0 18863766
# Cafe Coffee Day - The Square 3.5 303034

# %%
import json 
import requests

h = {'Accept': 'application/json' ,'user-key' :'53f964f0115fa5df324a07f7609f4eb2'}
r  =  requests.get('https://developers.zomato.com/api/v2.1/search?count=10&lat=28.6977&lon=77.1406&radius=4000&cuisines=193&sort=real_distance',headers = h)
data = r.json()
for i in data['restaurants']:
    print(i['restaurant']['name'], i ['restaurant']['user_rating']['aggregate_rating'],i['restaurant']['R']['res_id'], i['restaurant']['location']['locality'])
# Out:
# Themis Barbecue House 4.3 18204820 Netaji Subhash Place
# Barbeque Nation 4.1 9561 Netaji Subhash Place
# Amazings Kitchen 0 19370424 Prashant Vihar
# Anytime Chicken 0 19520153 Shalimar Bagh
# Moet's Barbeque 0 19238917 Alipur
# UBQ by Barbeque Nation 3.4 18889760 Rohini
# Chicken Adda 0 19179179 Rohini
# 7teen BBQ Bistro Bnq 3.9 18595610 Moti Nagar
# Pishori Chicken 0 19061375 Kirti Nagar
# The Rowdy Food 3.9 19501602 Tagore Garden

# %%
import json 
import requests

h = {'Accept': 'application/json' ,'user-key' :'53f964f0115fa5df324a07f7609f4eb2'}
r  =  requests.get('https://developers.zomato.com/api/v2.1/search?count=10&lat=28.6977&lon=77.1406&radius=4000&cuisines=193&sort=real_distance',headers = h)
data = r.json()
for i in data['restaurants']:
    print(i['restaurant']['name'], i ['restaurant']['user_rating']['aggregate_rating'],i['restaurant']['R']['res_id'], i['restaurant']['location']['locality'])
# Out:
# Themis Barbecue House 4.3 18204820 Netaji Subhash Place
# Barbeque Nation 4.1 9561 Netaji Subhash Place
# Amazings Kitchen 0 19370424 Prashant Vihar
# Anytime Chicken 0 19520153 Shalimar Bagh
# Moet's Barbeque 0 19238917 Alipur
# UBQ by Barbeque Nation 3.4 18889760 Rohini
# Chicken Adda 0 19179179 Rohini
# 7teen BBQ Bistro Bnq 3.9 18595610 Moti Nagar
# Pishori Chicken 0 19061375 Kirti Nagar
# The Rowdy Food 3.9 19501602 Tagore Garden

# %%
import json 
import requests

h = {'Accept': 'application/json' ,'user-key' :'53f964f0115fa5df324a07f7609f4eb2'}
r  =  requests.get('https://developers.zomato.com/api/v2.1/search?count=5&lat=28.6977&lon=77.1406&radius=4000&cuisines=193&sort=real_distance',headers = h)
data = r.json()
for i in data['restaurants']:
    print(i['restaurant']['name'], i ['restaurant']['user_rating']['aggregate_rating'],i['restaurant']['all_reviews']['reviews'])
# Out:
# Themis Barbecue House 4.3 [{'review': []}, {'review': []}, {'review': []}, {'review': []}, {'review': []}]
# Barbeque Nation 4.1 [{'review': []}, {'review': []}, {'review': []}, {'review': []}, {'review': []}]
# Amazings Kitchen 0 []
# Anytime Chicken 0 []
# Moet's Barbeque 0 [{'review': []}]

# %%
 
import json 
import requests

h = {'Accept': 'application/json' ,'user-key' :'53f964f0115fa5df324a07f7609f4eb2'}
r  =  requests.get('https://developers.zomato.com/api/v2.1/search?count=10&lat=28.6977&lon=77.1406&radius=4000&sort=real_distance',headers = h)
data = r.json()
for i in data['restaurants']:
    print(i['restaurant']['name'], i ['restaurant']['user_rating']['aggregate_rating'],i['restaurant']['R']['res_id'], i['restaurant']['location']['locality'])
# Out:
# The Paanwala 0 18683708 Pitampura
# Bharat Sweets 3.6 3333 Pitampura
# Mr. Momos 0 19341010 Pitampura
# Frontier 3.6 18888270 Pitampura
# Grub Garden 3.8 18980844 Pitampura
# My Choice Bakery 0 19544705 Pitampura
# Mega Bite 3.8 18366868 Pitampura
# Joint Fast Food Corner 0 19082219 Pitampura
# The Pizza Club 0 19342535 Pitampura
# Domino's Pizza 3.9 214 Pitampura

# %%
import json 
import requests

h = {'Accept': 'application/json' ,'user-key' :'53f964f0115fa5df324a07f7609f4eb2'}
r  =  requests.get('https://developers.zomato.com/api/v2.1/search?entity_id=104&entity_type=subzone&count=5&cuisines=73&category=6&sort=rating',headers = h)
data = r.json()
for i in data['restaurants']:
    print(i['restaurant']['name'], i ['restaurant']['user_rating']['aggregate_rating'],i['restaurant']['all_reviews']['reviews'])
# Out:
# Xero Degrees 4.3 [{'review': []}, {'review': []}, {'review': []}, {'review': []}, {'review': []}]
# Chaayos - Meri Wali Chai 4.1 [{'review': []}, {'review': []}, {'review': []}, {'review': []}, {'review': []}]
# The Art House Bar n Cafe 4.0 [{'review': []}, {'review': []}, {'review': []}, {'review': []}, {'review': []}]
# Cafe Coffee Day - The Square 3.5 [{'review': []}, {'review': []}, {'review': []}, {'review': []}, {'review': []}]

# %%
import json 
import requests

h = {'Accept': 'application/json' ,'user-key' :'53f964f0115fa5df324a07f7609f4eb2'}
r  =  requests.get('https://developers.zomato.com/api/v2.1/search?entity_id=104&entity_type=subzone&count=5&cuisines=73&category=6',headers = h)
data = r.json()
for i in data['restaurants']:
    print(i['restaurant']['name'], i ['restaurant']['user_rating']['aggregate_rating'],i['restaurant']['user_rating']['rating_text'])
# Out:
# Xero Degrees 4.3 Very Good
# Chaayos - Meri Wali Chai 4.1 Very Good
# The Art House Bar n Cafe 4.0 Very Good
# Cafe Coffee Day - The Square 3.5 Good

# %%
import json 
import requests

h = {'Accept': 'application/json' ,'user-key' :'53f964f0115fa5df324a07f7609f4eb2'}
r  =  requests.get('https://developers.zomato.com/api/v2.1/reviews?res_id=18429148&count=5',headers = h)
data = r.json()
for i in data['user_reviews']:
    print(i['review']['user']['name'], i ['review']['rating'], i['review']['review_text'])
# Out:
# Shradha Mahajan 5 Exceptional service - will be back! Sanjeev was extremely courteous, knowledgeable and smart. He made our anniversary meal during covid memorable. Don't waste time on random outlets - go for pa pa ya for your special occasions - it's a delight to your senses and safe for your health!
# Kavita Chaudhuri 5
# Amit Patnaik 2 Pedestrian spread for an expensive Sunday Brunch. Surreptitiously charged me for a bottle of water without offering house options. Didn't honour Zomato Pro commitment. Way past its prime and not in the same league as Yum Yum Cha.
# Rhea Suri 5 The service was perfect Vikram took care of us really well and was very courteous. The food was amazing
# Ananyaa Goel 5 This unconventional fried chicken bao is a MUST try for anyone who loves chicken! It's just wow.  I tried it with someone, we had to order another portion. Then I made some people try it, and we ended up ordering individual portions of the chicken bao!

# %%
## Open and read data file as specified in the question
## Print the required output in given format

import json 
import requests

h = {'Accept': 'application/json' ,'user-key' :'53f964f0115fa5df324a07f7609f4eb2'}
r  =  requests.get('https://developers.zomato.com/api/v2.1/search?count=10&lat=28.6977&lon=77.1406&radius=4000&sort=rating',headers = h)
data = r.json()
for i in data['restaurants']:
    print(i['restaurant']['name'], i ['restaurant']['user_rating']['aggregate_rating'],i['restaurant']['R']['res_id'], i['restaurant']['location']['locality'])
# Out:
# Indian Accent 4.9 2004 The Lodhi, Lodhi Road
# Pa Pa Ya 4.9 18429148 Select Citywalk Mall, Saket
# Cafe Lota 4.9 305525 Pragati Maidan
# The Big Chill 4.9 1614 Khan Market
# Kuremal Mohan Lal Kulfi Wale 4.9 303642 Chawri Bazar
# Dum-Pukht - ITC Maurya 4.9 2744 ITC Maurya, Chanakyapuri
# The Big Chill 4.9 8244 Khan Market
# Manhattan Bar & Brewery 4.8 303960 Global Foyer Mall, Golf Course Road
# Downtown - Diners & Living Beer Cafe 4.8 4959 Sector 29
# Cocktails & Dreams, Speakeasy 4.8 300716 Sector 15

# %%
import json 
import requests

h = {'Accept': 'application/json' ,'user-key' :'53f964f0115fa5df324a07f7609f4eb2'}
r  =  requests.get('https://developers.zomato.com/api/v2.1/reviews?res_id=18204820&count=5',headers = h)
data = r.json()
for i in data['user_reviews']:
    print(i['review']['user']['name'], i ['review']['rating'], i['review']['review_text'])
# Out:
# Aakriti Chandna 5 Had visited this place for a nice lunch buffet and thoroughly enjoyed everything from starters specially fish starter and salsa potatoes to main course to desserts... loved their dal makhani to the core... a messy dessert plate surely means a good time 😍... A must visit place ❤️
# Aradhya Sharma 4 The taste was really amazing 😍😍 I loved it and my family too I will visit again with my family it's really amazing
# Akshay( Not Just Food ) 4 Before this pandemic I visited a famous barbecue place that is themis Netaji Subhash Palace. It is a great place when indoor and outdoor seatings. A place with beautiful ambience and tasteful food.  They have a variety of vegetarian and nonvegetarian delicacies. We had vegetarian meal. And we loved it.  One must try.  A pocket friendly place 👍
# ...

# %%
import json 
import requests

h = {'Accept': 'application/json' ,'user-key' :'53f964f0115fa5df324a07f7609f4eb2'}
r  =  requests.get('https://developers.zomato.com/api/v2.1/reviews?res_id=18729557&count=5',headers = h)
data = r.json()
for i in data['user_reviews']:
    print(i['review']['user']['name'], i ['review']['rating'], i['review']['review_text'])
# Out:
# Vansh Batra 5 This is a superb place which has a great variety of food in very reasonable prices  Coming to my order I had red sauce pasta which was super delicious  Also had their peppy paneer pizza which was my favorite among all and was very cheesy Must try Also had thier two in one drink which was amazing too!! Had a lovely evening there Would totally recommend this outlet!!
# Manisha Batra 5 It's a amazing outlet located in cannaught place which serves a amazing variety of food  Also the interior of the outlet is quite awesome too Coming to my order I had paneer cottage cheesy fries which were damn yummy. Next on also have thier nutella shake and black current shake which was superb Had a great experience with this outlet  Would totally recommend this outlet !!
# Swati Gupta 5 Amazing food!! Superb presentation... I loved the ambience and the food was awesome that too in such an affordable price...
# ...
